# %% [markdown]
# # Combining & Exporting Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1. Create dictionary of data for experiment

# %%
# Define a dictionary containing january 2020 data
data1 = {'customer_id': ['6732', '767', '890', '635'],
        'month': ['jan-20', 'jan-20', 'jan-20', 'jan-20'],
        'purchased_meat': [0, 13, 3, 4],
        'purchased_alcohol': [1, 2, 10, 0],
        'purchased_snacks': [10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data
data2 = {'customer_id': ['6732', '767', '890', '635'],
        'month': ['feb-20', 'feb-20', 'feb-20', 'feb-20'],
        'purchased_meat': [0, 10, 5, 3],
        'purchased_alcohol': [2, 4, 14, 0],
        'purchased_snacks': [15, 3, 2, 6]}

# %%
# Convert the dictionary into dataframe
df = pd.DataFrame(data1, index = [0, 1, 2, 3])
df_1 = pd.DataFrame(data2, index = [0,1, 2, 3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  jan-20               0                  1                10
# 1         767  jan-20              13                  2                 5
# 2         890  jan-20               3                 10                 1
# 3         635  jan-20               4                  0                 7

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  feb-20               0                  2                15
# 1         767  feb-20              10                  4                 3
# 2         890  feb-20               5                 14                 2
# 3         635  feb-20               3                  0                 6

# %% [markdown]
# # 2. Concatenate Dataframe

# %%
# Create a list of DataFramesb
frames = [df, df_1]

# %%
# Check the output
frames
# Out:
# [  customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
#  0        6732  jan-20               0                  1                10
#  1         767  jan-20              13                  2                 5
#  2         890  jan-20               3                 10                 1
#  3         635  jan-20               4                  0                 7,
#    customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
#  0        6732  feb-20               0                  2                15
#  1         767  feb-20              10                  4                 3
#  2         890  feb-20               5                 14                 2
#  3         635  feb-20               3                  0                 6]

# %%
# Concatenat the dataframe uding the defult options
df_concat = pd.concat(frames)

# %%
# Check the output
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  jan-20               0                  1                10
# 1         767  jan-20              13                  2                 5
# 2         890  jan-20               3                 10                 1
# 3         635  jan-20               4                  0                 7
# 0        6732  feb-20               0                  2                15
# 1         767  feb-20              10                  4                 3
# 2         890  feb-20               5                 14                 2
# 3         635  feb-20               3                  0                 6

# %%
# Connecting the data frames using the axis =1 (create a wide-formate)
df_concat = pd.concat(frames, axis = 1)

# %%
# Output 
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  jan-20               0                  1                10
# 1         767  jan-20              13                  2                 5
# 2         890  jan-20               3                 10                 1
# 3         635  jan-20               4                  0                 7
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  feb-20               0                  2                15
# 1         767  feb-20              10                  4                 3
# 2         890  feb-20               5                 14                 2
# 3         635  feb-20               3                  0                 6

# %% [markdown]
# ## Join And Merge Data

# %%
# create a new dataframe
data3 = {'customer_id': ['6732', '767', '890', '635'],
        'month': ['jan-20', 'jan-20', 'jan-20', 'jan-20'],
        'days_purchased_on': [0, 10, 4, 1]}

# %%
#convert to data frames
df_2 = pd.DataFrame(data3, index = [0, 1, 2, 3])

# %%
# output
df_2
# Out:
#   customer_id   month  days_purchased_on
# 0        6732  jan-20                  0
# 1         767  jan-20                 10
# 2         890  jan-20                  4
# 3         635  jan-20                  1

# %%
# merge df and df_2 using key of  'customer_id'
df_merged = df.merge(df_2, on = 'customer_id')

# %%
#output
df_merged
# Out:
#   customer_id month_x  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  jan-20               0                  1                10
# 1         767  jan-20              13                  2                 5
# 2         890  jan-20               3                 10                 1
# 3         635  jan-20               4                  0                 7
#
#   month_y  days_purchased_on
# 0  jan-20                  0
# 1  jan-20                 10
# 2  jan-20                  4
# 3  jan-20                  1

# %%
# Merge df and df_2 using customer_id and month as a keys 
df_merged = df.merge(df_2, on = ['customer_id', 'month'])

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  jan-20               0                  1                10
# 1         767  jan-20              13                  2                 5
# 2         890  jan-20               3                 10                 1
# 3         635  jan-20               4                  0                 7
#
#    days_purchased_on
# 0                  0
# 1                 10
# 2                  4
# 3                  1

# %%
# Merge df and df_2 using customer_id and month as a keys, add a 'merge flag'
df_merged = df.merge(df_2, on = ['customer_id', 'month'], indicator = True)

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  jan-20               0                  1                10
# 1         767  jan-20              13                  2                 5
# 2         890  jan-20               3                 10                 1
# 3         635  jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 10   both
# 2                  4   both
# 3                  1   both

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          4
# left_only     0
# right_only    0
# Name: count, dtype: int64

# %%
# Test merge without overwriting
pd.merge(df, df_2, on = ['customer_id', 'month'], indicator = True)
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  jan-20               0                  1                10
# 1         767  jan-20              13                  2                 5
# 2         890  jan-20               3                 10                 1
# 3         635  jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 10   both
# 2                  4   both
# 3                  1   both
